# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('CarPrice_Assignment.csv')

# %%
data.describe()
# Out:
#         wheelbase   carlength    carwidth   carheight   curbweight  \
# count  205.000000  205.000000  205.000000  205.000000   205.000000
# mean    98.756585  174.049268   65.907805   53.724878  2555.565854
# std      6.021776   12.337289    2.145204    2.443522   520.680204
# min     86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%     94.500000  166.300000   64.100000   52.000000  2145.000000
# 50%     97.000000  173.200000   65.500000   54.100000  2414.000000
# 75%    102.400000  183.100000   66.900000   55.500000  2935.000000
# max    120.900000  208.100000   72.300000   59.800000  4066.000000
#
#        enginesize   boreratio      stroke  compressionratio  horsepower  \
# count  205.000000  205.000000  205.000000        205.000000  205.000000
# mean   126.907317    3.329756    3.255415         10.142537  104.117073
# std     41.642693    0.270844    0.313597          3.972040   39.544167
# min     61.000000    2.540000    2.070000          7.000000   48.000000
# ...

# %%
data.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 200    0
# 201    0
# 202    0
# 203    0
# 204    0
# Length: 205, dtype: int64

# %%
cat_col=(data.select_dtypes(include=['object']).columns)

# %%
type(cat_col)
# Out:
# pandas.core.indexes.base.Index

# %%
cat_col
# Out:
# Index(['fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel',
#        'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem'],
#       dtype='object')

# %%
for col in cat_col:
    unique_values=data[col].nunique()
    print(data[col].value_counts())
    print(f"Column '{col}'has {unique_values} unique value ")
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: CarName, Length: 147, dtype: int64
# Column 'CarName'has 147 unique value
# gas       185
# diesel     20
# Name: fueltype, dtype: int64
# Column 'fueltype'has 2 unique value
# std      168
# turbo     37
# Name: aspiration, dtype: int64
# Column 'aspiration'has 2 unique value
# four    115
# two      90
# Name: doornumber, dtype: int64
# Column 'doornumber'has 2 unique value
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64
# Column 'carbody'has 5 unique value
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64
# Column 'drivewheel'has 3 unique value
# front    202
# ...

# %%
#removing the column CarName

data=data.drop("CarName",axis=1)


print(data)
# Out:
#      car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0         1          3      gas        std        two  convertible        rwd
# 1         2          3      gas        std        two  convertible        rwd
# 2         3          1      gas        std        two    hatchback        rwd
# 3         4          2      gas        std       four        sedan        fwd
# 4         5          2      gas        std       four        sedan        4wd
# ..      ...        ...      ...        ...        ...          ...        ...
# 200     201         -1      gas        std       four        sedan        rwd
# 201     202         -1      gas      turbo       four        sedan        rwd
# 202     203         -1      gas        std       four        sedan        rwd
# 203     204         -1   diesel      turbo       four        sedan        rwd
# 204     205         -1      gas      turbo       four        sedan        rwd
#
# ...

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
data.count()
# Out:
# car_ID              205
# symboling           205
# fueltype            205
# aspiration          205
# doornumber          205
# carbody             205
# drivewheel          205
# enginelocation      205
# wheelbase           205
# carlength           205
# carwidth            205
# carheight           205
# curbweight          205
# enginetype          205
# cylindernumber      205
# enginesize          205
# fuelsystem          205
# boreratio           205
# stroke              205
# compressionratio    205
# horsepower          205
# peakrpm             205
# citympg             205
# highwaympg          205
# price               205
# dtype: int64

# %%
cat_col
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'],
#       dtype='object')

# %%
cat_col
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'],
#       dtype='object')

# %%
# remove row with value count 1

for col in cat_col:
    value_counts=data[col].value_counts()
    remove_indices=value_counts[value_counts==1].index
    data=data[~data[col].isin(remove_indices)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CarName'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data
# Out:
#      car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0         1          3      gas        std        two  convertible        rwd
# 1         2          3      gas        std        two  convertible        rwd
# 2         3          1      gas        std        two    hatchback        rwd
# 3         4          2      gas        std       four        sedan        fwd
# 4         5          2      gas        std       four        sedan        4wd
# ..      ...        ...      ...        ...        ...          ...        ...
# 200     201         -1      gas        std       four        sedan        rwd
# 201     202         -1      gas      turbo       four        sedan        rwd
# 202     203         -1      gas        std       four        sedan        rwd
# 203     204         -1   diesel      turbo       four        sedan        rwd
# 204     205         -1      gas      turbo       four        sedan        rwd
#
# ...

# %%
data.count()
# Out:
# car_ID              205
# symboling           205
# fueltype            205
# aspiration          205
# doornumber          205
# carbody             205
# drivewheel          205
# enginelocation      205
# wheelbase           205
# carlength           205
# carwidth            205
# carheight           205
# curbweight          205
# enginetype          205
# cylindernumber      205
# enginesize          205
# fuelsystem          205
# boreratio           205
# stroke              205
# compressionratio    205
# horsepower          205
# peakrpm             205
# citympg             205
# highwaympg          205
# price               205
# dtype: int64

# %%
for col in cat_col:
    unique_values=data[col].nunique()
    print(data[col].value_counts())
    print(f"Column '{col}'has {unique_values} unique value ")
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64
# Column 'fueltype'has 2 unique value
# std      168
# turbo     37
# Name: aspiration, dtype: int64
# Column 'aspiration'has 2 unique value
# four    115
# two      90
# Name: doornumber, dtype: int64
# Column 'doornumber'has 2 unique value
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64
# Column 'carbody'has 5 unique value
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64
# Column 'drivewheel'has 3 unique value
# front    202
# rear       3
# Name: enginelocation, dtype: int64
# Column 'enginelocation'has 2 unique value
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64
# Column 'enginetype'has 7 unique value
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# ...

# %%
print(data.columns)
# Out:
# Index(['fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel',
#        'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
data=data.drop("car_ID",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[313], line 1
# ----> 1 data=data.drop("car_ID",axis=1)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
data=data.drop("symboling",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[314], line 1
# ----> 1 data=data.drop("symboling",axis=1)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
data
# Out:
#     fueltype aspiration doornumber      carbody drivewheel enginelocation  \
# 0        gas        std        two  convertible        rwd          front
# 1        gas        std        two  convertible        rwd          front
# 2        gas        std        two    hatchback        rwd          front
# 3        gas        std       four        sedan        fwd          front
# 4        gas        std       four        sedan        4wd          front
# ..       ...        ...        ...          ...        ...            ...
# 200      gas        std       four        sedan        rwd          front
# 201      gas      turbo       four        sedan        rwd          front
# 202      gas        std       four        sedan        rwd          front
# 203   diesel      turbo       four        sedan        rwd          front
# 204      gas      turbo       four        sedan        rwd          front
#
#      wheelbase  carlength  carwidth  carheight  ...  enginesize fuelsystem  \
# ...

# %%
cat_col
# Out:
# Index(['fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel',
#        'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem'],
#       dtype='object')

# %%
for col in cat_col:
    unique_values=data[col].nunique()
    print(data[col].value_counts())
    print(f"Column '{col}'has {unique_values} unique value ")
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64
# Column 'fueltype'has 2 unique value
# std      168
# turbo     37
# Name: aspiration, dtype: int64
# Column 'aspiration'has 2 unique value
# four    115
# two      90
# Name: doornumber, dtype: int64
# Column 'doornumber'has 2 unique value
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64
# Column 'carbody'has 5 unique value
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64
# Column 'drivewheel'has 3 unique value
# front    202
# rear       3
# Name: enginelocation, dtype: int64
# Column 'enginelocation'has 2 unique value
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64
# Column 'enginetype'has 7 unique value
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# ...

# %%
data=pd.get_dummies(data,columns=cat_col)

# %%
data

# %%
#data visualise
import seaborn as sns

# %%
sns.pairplot(data)
plt.show()

# %%
plt.figure(figsize = (16, 10))
sns.heatmap(data.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
from sklearn.preprocessing import Normalizer

# %%
norm=Normalizer()
norm_data=norm.fit_transform(data)
data=norm_data

# %%
data

# %%
x=data[:,:-1]

# %%
x

# %%
x

# %%
y=data[:,-1]

# %%
y

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)

# %%
prediction=model.predict(x_test)

# %%
mse=np.mean((prediction-y_test)**2)

# %%
print(mse)

# %%
# Create a figure
fig = plt.figure()

# Plot each target vs features
for i in range(len(y.T)):
    plt.subplot(1, len(y.T), i + 1)
    plt.plot(x, y.T[i])
    plt.title(x.T[i].name)

# Show the figure
plt.show()
